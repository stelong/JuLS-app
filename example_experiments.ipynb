# %% [markdown]
# # Example Experiments

# %%
using JuLS
using CairoMakie

# %% [markdown]
# ## 1. Knapsack problem

# %%
# Instance
e = KnapsackExperiment("data/knapsack/ks_19_0")

# Model
model = init_model(e)

# Optimization
# optimize!(model, limit=IterationLimit(100))
optimize!(model, limit=StagnationLimit(20; max_iterations = 100))
# Out:
# ┌ Info: The DAG structure is instantiated.
# └ @ JuLS /Users/slongobardi/Projects/JuLS-app/src/dag/core/core.jl:152
# ┌ Info: The DAG invariants are instantiated.
# └ @ JuLS /Users/slongobardi/Projects/JuLS-app/src/dag/core/core.jl:158

# %%
plot_objective(model.run_metrics)

# %%
plot_solution(e, model)

# %% [markdown]
# ## 2. Travelling Salesman problem

# %%
# Instance
e = TSPExperiment("data/tsp/tsp_51_1")

# Heuristics
init = SimpleInitialization()
pick = SimulatedAnnealing()

# Model
model = init_model(e, init = init, pick = pick)

# Optimization
# optimize!(model, limit=IterationLimit(1000))
optimize!(model, limit=StagnationLimit(100; max_iterations = 1000))
# Out:
# ┌ Info: The DAG structure is instantiated.
# └ @ JuLS /Users/slongobardi/Projects/JuLS-app/src/dag/core/core.jl:152
# ┌ Info: The DAG invariants are instantiated.
# └ @ JuLS /Users/slongobardi/Projects/JuLS-app/src/dag/core/core.jl:158

# %%
plot_objective(model.run_metrics)

# %%
plot_solution(e, model)

# %% [markdown]
# ## 3. Graph Coloring problem

# %%
# Instance
e = GraphColoringExperiment("data/graph_coloring/gc_20_1", 3)

# Heuristics
init = SimpleInitialization()
neigh = RandomNeighbourhood(20, 1)
pick = SimulatedAnnealing()

# Model
model = init_model(e, init = init, neigh = neigh, pick = pick)

# Optimization
# optimize!(model, limit=IterationLimit(1000))
optimize!(model, limit=StagnationLimit(500; max_iterations = 10_000))
# Out:
# ┌ Info: The DAG structure is instantiated.
# └ @ JuLS /Users/slongobardi/Projects/JuLS-app/src/dag/core/core.jl:152
# ┌ Info: The DAG invariants are instantiated.
# └ @ JuLS /Users/slongobardi/Projects/JuLS-app/src/dag/core/core.jl:158

# %%
plot_objective(model.run_metrics)

# %%
plot_solution(e, model)
# Out:
# ┌ Warning: No feasible solution was found, plotting the current solution instead.
# └ @ JuLS /Users/slongobardi/Projects/JuLS-app/src/experiments/experiments.jl:103

# %% [markdown]
# # 4. Ticket Pricing problem

# %%
# Instance
e = TicketPricingExperiment("data/ticket_pricing/tp_3_300")

# Heuristics
init = SimpleInitialization()
neigh = TicketTransferNeighbourhood(e)
pick = GreedyMoveSelection()

# Model
model = init_model(e, init = init, neigh = neigh, pick = pick)

# Optimization
# optimize!(model, limit=IterationLimit(1000))
optimize!(model, limit=StagnationLimit(20; max_iterations = 1000))
# Out:
# ┌ Info: The DAG structure is instantiated.
# └ @ JuLS /Users/slongobardi/Projects/JuLS-app/src/dag/core/core.jl:152
# ┌ Info: The DAG invariants are instantiated.
# └ @ JuLS /Users/slongobardi/Projects/JuLS-app/src/dag/core/core.jl:158

# %%
plot_objective(model.run_metrics)

# %%
plot_solution(e, model)
